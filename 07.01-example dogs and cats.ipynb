# %%
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator,load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random 
import os
# Out:
# 25000
# 12500

# %%
########################
#print(os.listdir("input/dogs-vs-cats/test"))
print(len(os.listdir('input/dogs-vs-cats/train')))
print(len(os.listdir('input/dogs-vs-cats/test')))
# Out:
# 25000
# 12500

# %%
filenames=os.listdir("input/dogs-vs-cats/train/")
categories=[]
for filename in filenames:
    category=filename.split('.')[0]
    if category=='dog':
        categories.append(1)
    else:
        categories.append(0)
        
df=pd.DataFrame({
    'filename':filenames,
    'category':categories
})

# %%
########################
df.head()
# Out:
#         filename  category
# 0   dog.8011.jpg         1
# 1   cat.5077.jpg         0
# 2   dog.7322.jpg         1
# 3   cat.2718.jpg         0
# 4  cat.10151.jpg         0

# %%
########################
df.tail()
# Out:
#             filename  category
# 24995   dog.8008.jpg         1
# 24996   dog.1992.jpg         1
# 24997  dog.12412.jpg         1
# 24998   cat.2701.jpg         0
# 24999  cat.10148.jpg         0

# %%
########################
df['category'].value_counts().plot.bar()

# %%
########################
sample=random.choice(filenames)
image=load_img("input/dogs-vs-cats/train/" +sample)
plt.imshow(image)

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dropout,Flatten,Dense,Activation

image_width=128
image_height=128
image_size=(image_width,image_height)
image_channels=3

model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(image_width,image_height,image_channels)))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2,activation='softmax'))              #model.add(Dense(2,activation='softmax'))  

model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

model.summary()

from keras.callbacks import EarlyStopping,ReduceLROnPlateau

earlystop=EarlyStopping(patience=10)

learning_rate_reduce=ReduceLROnPlateau(monitor='val_acc',min_lr=0.0001)


callbacks=[earlystop,learning_rate_reduce]

df['category']=df['category'].replace({0:'cat',1:'dog'})
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               12845568
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,939,842
# Trainable params: 12,939,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_df,validate_df=train_test_split(df,test_size=0.20)
train_df=train_df.reset_index(drop=True)
validate_df=validate_df.reset_index(drop=True)

train_df['category'].value_counts().plot.bar()

validate_df['category'].value_counts().plot.bar()

total_train=train_df.shape[0]
total_validate=validate_df.shape[0]

print(total_train,total_validate)
# Out:
# 20000 5000

# %%
train_datagen=ImageDataGenerator(
rotation_range=15,
rescale=1/255,
zoom_range=0.1,
horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1)

train_generator=train_datagen.flow_from_dataframe(train_df,"input/dogs-vs-cats/train/",x_col='filename',y_col='category',target_size=image_size,class_mode='categorical',batch_size=64)

validation_datagen=ImageDataGenerator(
rotation_range=15,
rescale=1/255,
zoom_range=0.1,
horizontal_flip=True,width_shift_range=0.1,height_shift_range=0.1)

valid_generator=validation_datagen.flow_from_dataframe(validate_df,"input/dogs-vs-cats/train/",x_col='filename',y_col='category',target_size=image_size,class_mode='categorical',batch_size=64)

example_df=train_df.sample(n=1).reset_index(drop=True)
example_generator=train_datagen.flow_from_dataframe(
example_df,"input/dogs-vs-cats/train/",x_col='filename',y_col='category',target_size=image_size,class_mode='categorical'


)

batch_size=250
history=model.fit_generator(train_generator,epochs=20,validation_data=valid_generator,validation_steps=total_validate/batch_size,steps_per_epoch=total_train/batch_size,callbacks=callbacks)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.
# Found 1 validated image filenames belonging to 1 classes.
# WARNING:tensorflow:From <ipython-input-34-cbc32a27dc16>:25: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 80/80 [==============================] - ETA: 0s - loss: 0.8508 - accuracy: 0.5130WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 565s 7s/step - loss: 0.8508 - accuracy: 0.5130 - val_loss: 0.6675 - val_accuracy: 0.6047
# Epoch 2/20
# 80/80 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.5723WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 419s 5s/step - loss: 0.6659 - accuracy: 0.5723 - val_loss: 0.6545 - val_accuracy: 0.6047
# Epoch 3/20
# 80/80 [==============================] - ETA: 0s - loss: 0.6725 - accuracy: 0.5711WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 649s 8s/step - loss: 0.6725 - accuracy: 0.5711 - val_loss: 0.6718 - val_accuracy: 0.5938
# Epoch 4/20
# 80/80 [==============================] - ETA: 0s - loss: 0.6593 - accuracy: 0.6143WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 372s 5s/step - loss: 0.6593 - accuracy: 0.6143 - val_loss: 0.6685 - val_accuracy: 0.5852
# Epoch 5/20
# 80/80 [==============================] - ETA: 0s - loss: 0.6663 - accuracy: 0.6038WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 384s 5s/step - loss: 0.6663 - accuracy: 0.6038 - val_loss: 0.6618 - val_accuracy: 0.6102
# Epoch 6/20
# 80/80 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.6468WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 436s 5s/step - loss: 0.6307 - accuracy: 0.6468 - val_loss: 0.6154 - val_accuracy: 0.6633
# Epoch 7/20
# 80/80 [==============================] - ETA: 0s - loss: 0.6066 - accuracy: 0.6793WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 361s 5s/step - loss: 0.6066 - accuracy: 0.6793 - val_loss: 0.6540 - val_accuracy: 0.6336
# Epoch 8/20
# 80/80 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.6627WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 393s 5s/step - loss: 0.6158 - accuracy: 0.6627 - val_loss: 0.6271 - val_accuracy: 0.6711
# Epoch 9/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5898 - accuracy: 0.6920WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 348s 4s/step - loss: 0.5898 - accuracy: 0.6920 - val_loss: 0.5695 - val_accuracy: 0.6992
# Epoch 10/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.6973WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 384s 5s/step - loss: 0.5829 - accuracy: 0.6973 - val_loss: 0.5562 - val_accuracy: 0.7086
# Epoch 11/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5480 - accuracy: 0.7148WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 448s 6s/step - loss: 0.5480 - accuracy: 0.7148 - val_loss: 0.5532 - val_accuracy: 0.7156
# Epoch 12/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5498 - accuracy: 0.7195WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 424s 5s/step - loss: 0.5498 - accuracy: 0.7195 - val_loss: 0.5357 - val_accuracy: 0.7336
# Epoch 13/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5602 - accuracy: 0.7076WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 482s 6s/step - loss: 0.5602 - accuracy: 0.7076 - val_loss: 0.5315 - val_accuracy: 0.7359
# Epoch 14/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5115 - accuracy: 0.7461WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 838s 10s/step - loss: 0.5115 - accuracy: 0.7461 - val_loss: 0.5131 - val_accuracy: 0.7273
# Epoch 15/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5264 - accuracy: 0.7361WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 872s 11s/step - loss: 0.5264 - accuracy: 0.7361 - val_loss: 0.5027 - val_accuracy: 0.7477
# Epoch 16/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5163 - accuracy: 0.7432WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 871s 11s/step - loss: 0.5163 - accuracy: 0.7432 - val_loss: 0.5023 - val_accuracy: 0.7680
# Epoch 17/20
# 80/80 [==============================] - ETA: 0s - loss: 0.5104 - accuracy: 0.7443 WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 956s 12s/step - loss: 0.5104 - accuracy: 0.7443 - val_loss: 0.4869 - val_accuracy: 0.7758
# Epoch 18/20
# 80/80 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.7567WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 747s 9s/step - loss: 0.4941 - accuracy: 0.7567 - val_loss: 0.4786 - val_accuracy: 0.7648
# Epoch 19/20
# 80/80 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.7570WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 856s 11s/step - loss: 0.4890 - accuracy: 0.7570 - val_loss: 0.5190 - val_accuracy: 0.7297
# Epoch 20/20
# 80/80 [==============================] - ETA: 0s - loss: 0.4747 - accuracy: 0.7793 WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 80/80 [==============================] - 1632s 20s/step - loss: 0.4747 - accuracy: 0.7793 - val_loss: 0.4417 - val_accuracy: 0.7977

# %%
plt.plot(history.history['val_loss'],color='r')
plt.plot(history.history['accuracy'],color='black')
plt.plot(history.history['loss'],color='black')
plt.plot(history.history['val_accuracy'],color='yellow')
plt.show()

# %%
test_filenames=os.listdir('input/dogs-vs-cats/test')

test_df=pd.DataFrame({
    'filename':test_filenames
})
print(len(os.listdir('input/dogs-vs-cats/test')))


test_gen=ImageDataGenerator(rescale=1/255)

test_generator=test_gen.flow_from_dataframe(
test_df,'input/dogs-vs-cats/test/',x_col='filename',y_col=None,class_mode=None,target_size=image_size,batch_size=64,shuffle=False)


predict=model.predict_generator(test_generator)

test_df['category']=np.argmax(predict,axis=-1)
label_map=dict((v,k) for k,v in train_generator.class_indices.items())

test_df['category']=test_df['category'].replace(label_map)


test_df['category']=test_df['category'].replace({'dog':1,'cat':0})
test_df['category'].value_counts().plot.bar()
# Out:
# 12500
# Found 12500 validated image filenames.
# WARNING:tensorflow:From <ipython-input-37-84ba6b234537>:15: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
sample_test=test_df.head(15)
sample_test.head()
plt.figure(figsize=(15,25))
for index,row in sample_test.iterrows():
    filename=row['filename']
    category=row['category']
    img=load_img('input/dogs-vs-cats/test/'+ filename,target_size=image_size)
    plt.subplot(6,3,index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')')
    
plt.show()

# %%
submission_df=test_df.copy()
submission_df['id']=submission_df['filename'].str.split('.').str[0]
submission_df['label']=submission_df['category']
submission_df.drop(['filename','category'],axis=1,inplace=True)
submission_df.to_csv('submission.csv',index=False)
